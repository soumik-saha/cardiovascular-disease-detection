# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
dataset_path = 'data.csv'
df = pd.read_csv(dataset_path)

# Remove duplicates
df.drop_duplicates(inplace=True)

# Check the overall structure of the dataset
print("Dataset shape:", df.shape)
print()

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())
print()

# Check for missing values
print("Missing values:")
print(df.isnull().sum())
print()

# Analyze the target variable ('cardio')
print("Target variable (cardio) distribution:")
print(df['cardio'].value_counts())
print()

# Example: Visualize the distribution of Age
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# Save the plot as a PNG file
plt.savefig('age_distribution.png')

# Example: Visualize the distribution of Gender
plt.hist(df['gender'], bins=2, color='lightgreen', edgecolor='black')
plt.xlabel('Gender (1: Female, 2: Male)')
plt.ylabel('Frequency')
plt.title('Distribution of Gender')
plt.show()

# Save the plot as a PNG file
plt.savefig('gender_distribution.png')
# Out:
# Dataset shape: (70000, 13)
#
# First few rows of the dataset:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0
#
# Missing values:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define a modern color palette
colors = ['blue', 'orange']

# Create subplots with 1 row and 3 columns, and set the figure size
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# --- Plot the stacked bar chart for the target variable distribution ('cardio') ---
labels_cardio = ['No Heart Disease', 'Heart Disease']
counts_cardio = df['cardio'].value_counts()
total_cardio = counts_cardio.sum()
axes[0].bar(labels_cardio, counts_cardio, color=colors, width=1)
axes[0].set_title("Cardiovascular Disease Distribution", fontsize=14, ha='center')
axes[0].grid(axis='y', linestyle='--', alpha=0.7)

# Annotate bars with percentages
for i, count in enumerate(counts_cardio):
    percentage = count / total_cardio * 100
    axes[0].text(i, count, f"{percentage:.1f}%", ha='center', va='bottom', fontsize=12)

# Draw a line and display the count of data on the left side of the subplot
axes[0].annotate(f"{total_cardio} data",
                 xy=(0, total_cardio), xycoords='data',
                 xytext=(-40, total_cardio), textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", color="black"),
                 fontsize=12, ha='center', va='center')

# --- Plot the bar chart for distribution of Smoking Status ('smoke') ---
labels_smoke = ['Non-Smoker', 'Smoker']
counts_smoke = df['smoke'].value_counts()
total_smoke = counts_smoke.sum()
axes[1].bar(labels_smoke, counts_smoke, color=colors, width=1)
axes[1].set_title("Smoking Status Distribution", fontsize=14, ha='center')
axes[1].grid(axis='y', linestyle='--', alpha=0.7)

# Annotate bars with percentages
for i, count in enumerate(counts_smoke):
    percentage = count / total_smoke * 100
    axes[1].text(i, count, f"{percentage:.1f}%", ha='center', va='bottom', fontsize=12)

# Draw a line and display the count of data on the left side of the subplot
axes[1].annotate(f"{total_smoke} data",
                 xy=(0, total_smoke), xycoords='data',
                 xytext=(-40, total_smoke), textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", color="black"),
                 fontsize=12, ha='center', va='center')

# --- Plot the bar chart for Alcohol Consumption ('alco') ---
labels_alco = ['Non-Drinker', 'Drinker']
counts_alco = df['alco'].value_counts()
total_alco = counts_alco.sum()
axes[2].bar(labels_alco, counts_alco, color=colors, width=1)
axes[2].set_title("Alcohol Consumption Distribution", fontsize=14, ha='center')
axes[2].grid(axis='y', linestyle='--', alpha=0.7)

# Annotate bars with percentages
for i, count in enumerate(counts_alco):
    percentage = count / total_alco * 100
    axes[2].text(i, count, f"{percentage:.1f}%", ha='center', va='bottom', fontsize=12)

# Draw a line and display the count of data on the left side of the subplot
axes[2].annotate(f"{total_alco} data",
                 xy=(0, total_alco), xycoords='data',
                 xytext=(-40, total_alco), textcoords='offset points',
                 arrowprops=dict(arrowstyle="->", color="black"),
                 fontsize=12, ha='center', va='center')

# Set the font size and style for labels
for ax in axes:
    ax.set_ylabel(None)
    ax.set_title(ax.get_title(), fontsize=14)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)

    # Disable grid lines
    ax.grid(False)

    # Remove side ticks for the y-axis
    ax.set_yticks([])

    # Center-align the x-axis labels
    ax.set_xticklabels(ax.get_xticklabels(), ha='center')

# Adjust spacing between subplots
plt.tight_layout(pad=2)

# Display the plots
plt.show()
# Out:
# <ipython-input-2-57742abfa681>:87: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), ha='center')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a single subplot with 2 histogram layers and set the figure size
fig, ax = plt.subplots(figsize=(10, 5))

# Plot histogram for 'Age' where there is no heart disease and color the bars differently
sns.histplot(data=df[df['cardio'] == 0], x='age', color='blue', label='No Disease', ax=ax)

# Plot histogram for 'Age' where there is heart disease and color the bars differently
sns.histplot(data=df[df['cardio'] == 1], x='age', color='orange', label='Disease', ax=ax)

# Set the title and other labels
ax.set_title("Age Distribution with No Disease and Disease")
ax.set_xlabel("Age")
ax.set_ylabel("Count")

# Show the legend
ax.legend()

# Set a higher DPI for better quality (e.g., 300 DPI)
plt.savefig('age_distribution_combined_final.pdf', dpi=300)

# Display the plot (optional, comment this line if you only want to save the PDF and not display the plot)
plt.show()

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Define the target column ('cardio' in your case)
target_column = 'cardio'

# Sort the correlation values with respect to the target variable
correlation_with_target = correlation_matrix[target_column].drop(target_column).sort_values(ascending=False)

# Print the highly correlated columns to the target variable
print("Highly correlated columns to", target_column, "in descending order:")
for col, correlation in correlation_with_target.items():
    print(col, ":", correlation)
# Out:
# Highly correlated columns to cardio in descending order:
# age : 0.23815922744230844
# cholesterol : 0.2211472739123984
# weight : 0.18165956179862647
# gluc : 0.08930688732430264
# ap_lo : 0.06571869614919028
# ap_hi : 0.05447505392686579
# gender : 0.008109491913122303
# id : 0.003799389187199488
# alco : -0.007330231723202663
# height : -0.01082105833100495
# smoke : -0.015485935661367784
# active : -0.03565324811519037

# %%
# Select the specified features from your dataset
selected_features = ['cardio', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']
df_selected = df[selected_features]

# Print the selected features and target column
print("Selected features and target column:")
print(df_selected)

# Save df_selected to a CSV file (optional)
df_selected.to_csv('df_selected.csv', index=False)
# Out:
# Selected features and target column:
#        cardio    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0           0  18393       2     168    62.0    110     80            1     1
# 1           1  20228       1     156    85.0    140     90            3     1
# 2           1  18857       1     165    64.0    130     70            3     1
# 3           1  17623       2     169    82.0    150    100            1     1
# 4           0  17474       1     156    56.0    100     60            1     1
# ...       ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995       0  19240       2     168    76.0    120     80            1     1
# 69996       1  22601       1     158   126.0    140     90            2     2
# 69997       1  19066       2     183   105.0    180     90            3     1
# 69998       1  22431       1     163    72.0    135     80            1     2
# ...

# %%
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTEENN

# Separate the features and target variable
X_train = df_selected.drop("cardio", axis=1)  # Use 'cardio' as the target
y_train = df_selected["cardio"]

# Perform SMOTEENN oversampling on the resampled data
smote_enn = SMOTEENN(random_state=42)
X_train_resampled_smoteenn, y_train_resampled_smoteenn = smote_enn.fit_resample(X_train, y_train)

# Perform RandomOverSampler on the training data
random_oversampler = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = random_oversampler.fit_resample(X_train_resampled_smoteenn, y_train_resampled_smoteenn)

# Combine the resampled features and target variable into a single DataFrame
resampled_data = pd.concat([X_train_resampled, y_train_resampled], axis=1)

# Separate the instances with 0 and 1 values for the target variable 'cardio'
data_0 = resampled_data[resampled_data["cardio"] == 0]
data_1 = resampled_data[resampled_data["cardio"] == 1]

# Sample 3000 instances from each class
data_0_sample = data_0.sample(n=3000, random_state=42)
data_1_sample = data_1.sample(n=3000, random_state=42)

# Concatenate the sampled instances into a single DataFrame
first_csv_data = pd.concat([data_0_sample, data_1_sample])

# Drop the sampled instances from the original data to get the remaining instances
remaining_data_0 = data_0.drop(data_0_sample.index)
remaining_data_1 = data_1.drop(data_1_sample.index)
second_csv_data = pd.concat([remaining_data_0, remaining_data_1])

# Save the DataFrames to CSV files
first_csv_data.to_csv("test.csv", index=False)
second_csv_data.to_csv("heart_disease_train_resampled.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load the training dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the model (choose your preferred model, e.g., DNN, CNN, or RNN)
# Here's an example with a DNN:
def create_nn_model(input_shape):
    model_dnn = Sequential()
    model_dnn.add(Dense(64, activation='relu', input_shape=(input_shape,)))
    model_dnn.add(Dense(32, activation='relu'))
    model_dnn.add(Dense(1, activation='sigmoid'))
    return model_dnn

nn_model = create_nn_model(X_normalized.shape[1])
nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Implement Early Stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = nn_model.fit(
    X_train,
    y_train,
    epochs=50,  # Adjust the number of epochs as needed
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6641 - loss: 0.6011 - val_accuracy: 0.7624 - val_loss: 0.4890
# Epoch 2/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7820 - loss: 0.4644 - val_accuracy: 0.7751 - val_loss: 0.4724
# Epoch 3/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7876 - loss: 0.4512 - val_accuracy: 0.7794 - val_loss: 0.4595
# Epoch 4/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7910 - loss: 0.4400 - val_accuracy: 0.7829 - val_loss: 0.4514
# Epoch 5/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7938 - loss: 0.4349 - val_accuracy: 0.7863 - val_loss: 0.4507
# ...

# %%
# !pip install keras-tuner --upgrade

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam  # Fix the optimizer import
import keras_tuner as kt

# Load the training dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Hyperparameter tuning function
def build_model(hp):
    model = Sequential()

    # Add an Input layer to replace input_shape in Dense layers
    model.add(Input(shape=(X_train.shape[1],)))

    # Tuning the number of units in the first Dense layer
    hp_units1 = hp.Int('units1', min_value=32, max_value=512, step=32)
    model.add(Dense(units=hp_units1, activation='relu'))

    # Tuning the number of layers and units in each layer
    for i in range(hp.Int('num_layers', 1, 3)):  # Allows between 1 and 3 hidden layers
        hp_units = hp.Int(f'units_{i+2}', min_value=32, max_value=512, step=32)
        model.add(Dense(units=hp_units, activation='relu'))

    # Output layer
    model.add(Dense(1, activation='sigmoid'))

    # Tuning optimizer and learning rate
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(optimizer=Adam(learning_rate=hp_learning_rate),  # Correct Adam import
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    return model

# Initialize the tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # You can increase this for more exhaustive search
    executions_per_trial=2,
    directory='keras_tuner_dir',
    project_name='heart_disease_dnn')

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Perform the hyperparameter search
tuner.search(X_train, y_train, epochs=50, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the best model
best_model = tuner.hypermodel.build(best_hps)

# Train the model with the optimal hyperparameters
history = best_model.fit(X_train, y_train, epochs=50, validation_data=(X_val, y_val), callbacks=[early_stopping])

# Plotting the training history to visualize performance improvements
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# Evaluate the model
val_loss, val_accuracy = best_model.evaluate(X_val, y_val)
print(f"Best validation accuracy: {val_accuracy:.4f}")
# Out:
# Trial 10 Complete [00h 02m 52s]
# val_accuracy: 0.9463667869567871
#
# Best val_accuracy So Far: 0.9463667869567871
# Total elapsed time: 00h 37m 18s
# Epoch 1/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7073 - loss: 0.5538 - val_accuracy: 0.7705 - val_loss: 0.4817
# Epoch 2/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7869 - loss: 0.4621 - val_accuracy: 0.7829 - val_loss: 0.4503
# Epoch 3/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7836 - loss: 0.4508 - val_accuracy: 0.7388 - val_loss: 0.5290
# Epoch 4/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7864 - loss: 0.4492 - val_accuracy: 0.7886 - val_loss: 0.4406
# Epoch 5/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7923 - loss: 0.4333 - val_accuracy: 0.8013 - val_loss: 0.4254
# Epoch 6/50
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7948 - loss: 0.4276 - val_accuracy: 0.7958 - val_loss: 0.4300
# Epoch 7/50
# ...

# %%
# Get the best hyperparameters from the search
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Print the best hyperparameters
print("Best Hyperparameters:")
for param in best_hps.values.keys():
    print(f"{param}: {best_hps.get(param)}")
# Out:
# Best Hyperparameters:
# units1: 192
# num_layers: 2
# units_2: 256
# learning_rate: 0.01
# units_3: 320
# units_4: 512

# %%
# Get all the trials
trials = tuner.oracle.get_best_trials(num_trials=10)

# Display the top 5 trials with their hyperparameters and results
for i, trial in enumerate(trials):
    print(f"Trial {i+1} Best Hyperparameters:")
    for param, value in trial.hyperparameters.values.items():
        print(f"  {param}: {value}")
    print(f"  Validation Accuracy: {trial.score}")
# Out:
# Trial 1 Best Hyperparameters:
#   units1: 192
#   num_layers: 2
#   units_2: 256
#   learning_rate: 0.01
#   units_3: 320
#   units_4: 512
#   Validation Accuracy: 0.9463667869567871
# Trial 2 Best Hyperparameters:
#   units1: 384
#   num_layers: 2
#   units_2: 128
#   learning_rate: 0.001
#   units_3: 256
#   units_4: 384
#   Validation Accuracy: 0.9439157843589783
# Trial 3 Best Hyperparameters:
#   units1: 448
#   num_layers: 3
#   units_2: 480
#   learning_rate: 0.01
#   units_3: 32
#   units_4: 32
#   Validation Accuracy: 0.943050742149353
# Trial 4 Best Hyperparameters:
#   units1: 512
#   num_layers: 3
#   units_2: 288
#   learning_rate: 0.001
#   units_3: 288
#   units_4: 352
#   Validation Accuracy: 0.9426182210445404
# Trial 5 Best Hyperparameters:
#   units1: 384
#   num_layers: 3
#   units_2: 224
#   learning_rate: 0.0001
#   units_3: 416
#   units_4: 128
#   Validation Accuracy: 0.9354094564914703
# Trial 6 Best Hyperparameters:
#   units1: 448
#   num_layers: 3
# ...

# %%
# Save the best model
best_model.save('best_heart_disease_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

# Load the saved model
loaded_model = load_model('best_heart_disease_model.h5')

# Compile the model with the same settings used during training
loaded_model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy', metrics=['accuracy'])

# Evaluate the model
loaded_model.evaluate(X_val, y_val)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9460 - loss: 0.1553
# [0.15513433516025543, 0.9443483352661133]

# %% [markdown]
# ADDING MORE LAYERS

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization

# Load the training dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the Deep Neural Network model
def create_deep_nn_model(input_shape):
    model_dnn = Sequential()

    # Layer 1
    model_dnn.add(Dense(192, activation='relu', input_shape=(input_shape,)))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.2))  # Dropout to prevent overfitting

    # Layer 2
    model_dnn.add(Dense(256, activation='relu'))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.3))

    # Layer 3
    model_dnn.add(Dense(320, activation='relu'))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.4))

    # Layer 4
    model_dnn.add(Dense(512, activation='relu'))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.4))

    # Output layer
    model_dnn.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

    return model_dnn

# Instantiate and compile the model
nn_model = create_deep_nn_model(X_normalized.shape[1])
nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Implement Early Stopping and Learning Rate Scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# Train the model with more layers and advanced regularization techniques
history = nn_model.fit(
    X_train,
    y_train,
    epochs=100,  # Increased the number of epochs for better training
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 15s 15ms/step - accuracy: 0.6917 - loss: 0.6921 - val_accuracy: 0.7353 - val_loss: 0.5255 - learning_rate: 0.0010
# Epoch 2/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7540 - loss: 0.5159 - val_accuracy: 0.7558 - val_loss: 0.5008 - learning_rate: 0.0010
# Epoch 3/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7738 - loss: 0.4795 - val_accuracy: 0.7811 - val_loss: 0.4562 - learning_rate: 0.0010
# Epoch 4/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7743 - loss: 0.4732 - val_accuracy: 0.7907 - val_loss: 0.4573 - learning_rate: 0.0010
# Epoch 5/100
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.regularizers import l2

# Load the training dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the Deep Neural Network model using Input Layer with L2 regularization
def create_deep_nn_model(input_shape):
    model_dnn = Sequential()

    # Input Layer
    model_dnn.add(Input(shape=(input_shape,)))

    # Layer 1
    model_dnn.add(Dense(192, activation='relu', kernel_regularizer=l2(0.001)))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.3))  # Slightly higher dropout

    # Layer 2
    model_dnn.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.4))  # Slightly higher dropout

    # Layer 3
    model_dnn.add(Dense(320, activation='relu', kernel_regularizer=l2(0.001)))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.4))

    # Layer 4
    model_dnn.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
    model_dnn.add(BatchNormalization())
    model_dnn.add(Dropout(0.5))  # Higher dropout to reduce overfitting

    # Output Layer
    model_dnn.add(Dense(1, activation='sigmoid'))

    return model_dnn

# Instantiate and compile the model
nn_model = create_deep_nn_model(X_normalized.shape[1])
nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Implement Early Stopping and Learning Rate Scheduler
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# Train the model with more layers and advanced regularization techniques
history = nn_model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.6856 - loss: 1.6106 - val_accuracy: 0.7488 - val_loss: 1.2923 - learning_rate: 0.0010
# Epoch 2/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7378 - loss: 1.2504 - val_accuracy: 0.7710 - val_loss: 1.0681 - learning_rate: 0.0010
# Epoch 3/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7662 - loss: 1.0394 - val_accuracy: 0.7719 - val_loss: 0.9050 - learning_rate: 0.0010
# Epoch 4/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7780 - loss: 0.8769 - val_accuracy: 0.7728 - val_loss: 0.7766 - learning_rate: 0.0010
# Epoch 5/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7758 - loss: 0.7559 - val_accuracy: 0.7785 - val_loss: 0.6748 - learning_rate: 0.0010
# Epoch 6/100
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7762 - loss: 0.6596 - val_accuracy: 0.7892 - val_loss: 0.5986 - learning_rate: 0.0010
# Epoch 7/100
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Residual Connection (ResNet-like block)
    residual = Dense(512, activation='relu')(model_input)
    x = Add()([x, residual])

    # Layer 4
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Set up Early Stopping and ReduceLROnPlateau
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.6712 - loss: 2.5596 - val_accuracy: 0.6427 - val_loss: 2.2571 - learning_rate: 0.0010
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7470 - loss: 2.0897 - val_accuracy: 0.7757 - val_loss: 1.8668 - learning_rate: 0.0010
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7722 - loss: 1.7014 - val_accuracy: 0.7748 - val_loss: 1.4576 - learning_rate: 0.0010
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7747 - loss: 1.3692 - val_accuracy: 0.7809 - val_loss: 1.1693 - learning_rate: 0.0010
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7767 - loss: 1.1066 - val_accuracy: 0.7768 - val_loss: 0.9567 - learning_rate: 0.0010
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7886 - loss: 0.8977 - val_accuracy: 0.6877 - val_loss: 0.9037 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Residual Connection (ResNet-like block)
    residual = Dense(512, activation='relu')(model_input)
    x = Add()([x, residual])

    # Layer 4
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Set up ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - accuracy: 0.6652 - loss: 2.5276 - val_accuracy: 0.6514 - val_loss: 2.2267 - learning_rate: 0.0010
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7439 - loss: 2.0356 - val_accuracy: 0.7601 - val_loss: 1.8052 - learning_rate: 0.0010
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7680 - loss: 1.6283 - val_accuracy: 0.7722 - val_loss: 1.3731 - learning_rate: 0.0010
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7696 - loss: 1.2962 - val_accuracy: 0.7748 - val_loss: 1.0870 - learning_rate: 0.0010
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7900 - loss: 1.0232 - val_accuracy: 0.7803 - val_loss: 0.8880 - learning_rate: 0.0010
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7820 - loss: 0.8440 - val_accuracy: 0.7935 - val_loss: 0.7344 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Residual Connection (ResNet-like block)
    residual = Dense(512, activation='relu')(model_input)
    x = Add()([x, residual])

    # Layer 4
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Set up ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr]
)

# Evaluate the model on the validation set
loss, accuracy = complex_nn_model.evaluate(X_val, y_val)
print(f'Validation Accuracy: {accuracy:.4f}')

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 18s 32ms/step - accuracy: 0.6762 - loss: 2.5067 - val_accuracy: 0.7197 - val_loss: 2.2426 - learning_rate: 0.0010
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7542 - loss: 2.0167 - val_accuracy: 0.7693 - val_loss: 1.7718 - learning_rate: 0.0010
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7636 - loss: 1.6328 - val_accuracy: 0.7765 - val_loss: 1.3551 - learning_rate: 0.0010
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7857 - loss: 1.2617 - val_accuracy: 0.7771 - val_loss: 1.0735 - learning_rate: 0.0010
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7840 - loss: 0.9981 - val_accuracy: 0.7832 - val_loss: 0.8600 - learning_rate: 0.0010
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7856 - loss: 0.8180 - val_accuracy: 0.6335 - val_loss: 0.9475 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add, LeakyReLU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Residual Connection (ResNet-like block)
    residual = Dense(1024, activation='relu')(model_input)
    x = Add()([x, residual])

    # Layer 4
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Additional Layers
    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Set up ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 27s 49ms/step - accuracy: 0.6177 - loss: 4.7394 - val_accuracy: 0.5115 - val_loss: 4.1028 - learning_rate: 0.0010
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7372 - loss: 3.7736 - val_accuracy: 0.7065 - val_loss: 3.2391 - learning_rate: 0.0010
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7606 - loss: 2.9228 - val_accuracy: 0.7661 - val_loss: 2.3986 - learning_rate: 0.0010
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7661 - loss: 2.2096 - val_accuracy: 0.7780 - val_loss: 1.7791 - learning_rate: 0.0010
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7751 - loss: 1.6647 - val_accuracy: 0.7829 - val_loss: 1.3570 - learning_rate: 0.0010
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7743 - loss: 1.2766 - val_accuracy: 0.7811 - val_loss: 1.0766 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %% [markdown]
# Added More layers

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(4096, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 4
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Additional Layers
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Residual Connection
    residual = Dense(64, activation='relu')(model_input)
    x = Add()([x, residual])

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Set up ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 28s 58ms/step - accuracy: 0.6055 - loss: 8.5715 - val_accuracy: 0.6877 - val_loss: 6.6405 - learning_rate: 0.0010
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7518 - loss: 5.9079 - val_accuracy: 0.6955 - val_loss: 4.3468 - learning_rate: 0.0010
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7609 - loss: 3.7867 - val_accuracy: 0.7526 - val_loss: 2.7784 - learning_rate: 0.0010
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.7670 - loss: 2.4605 - val_accuracy: 0.7745 - val_loss: 1.8584 - learning_rate: 0.0010
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7673 - loss: 1.6990 - val_accuracy: 0.7837 - val_loss: 1.3499 - learning_rate: 0.0010
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7889 - loss: 1.2529 - val_accuracy: 0.7858 - val_loss: 1.0492 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %%
# prompt: call confusion matrix, show f1 score, recall, accuracy.

from sklearn.metrics import confusion_matrix, classification_report

# Make predictions on the validation set
y_pred_prob = complex_nn_model.predict(X_val)
y_pred = (y_pred_prob > 0.5).astype(int)

# Generate the confusion matrix
cm = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:")
print(cm)

# Print classification report (includes F1-score, recall, precision, accuracy)
print("\nClassification Report:")
print(classification_report(y_val, y_pred))
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Confusion Matrix:
# [[1679   45]
#  [  71 1673]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1724
#            1       0.97      0.96      0.97      1744
#
#     accuracy                           0.97      3468
#    macro avg       0.97      0.97      0.97      3468
# weighted avg       0.97      0.97      0.97      3468

# %%
CURRENT BEST END

# %%
NEW APPROACH

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(4096, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 4
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Additional Layers
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Additional Dense Layers for increased complexity
    x = Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(32, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(16, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Residual Connection
    residual = Dense(16, activation='relu')(model_input)
    x = Add()([x, residual])

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Set up ReduceLROnPlateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr]
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 40s 81ms/step - accuracy: 0.5232 - loss: 9.0195 - val_accuracy: 0.6488 - val_loss: 7.6142 - learning_rate: 0.0010
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5620 - loss: 7.2418 - val_accuracy: 0.6373 - val_loss: 5.8057 - learning_rate: 0.0010
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.6234 - loss: 5.4304 - val_accuracy: 0.6292 - val_loss: 4.3199 - learning_rate: 0.0010
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7032 - loss: 3.9987 - val_accuracy: 0.6528 - val_loss: 3.2445 - learning_rate: 0.0010
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7253 - loss: 3.0318 - val_accuracy: 0.6943 - val_loss: 2.5039 - learning_rate: 0.0010
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7446 - loss: 2.3411 - val_accuracy: 0.7116 - val_loss: 1.9968 - learning_rate: 0.0010
# Epoch 7/200
# ...

# %%
# prompt: call confusion matrix, show f1 score, recall, accuracy.

from sklearn.metrics import confusion_matrix, classification_report

# Make predictions on the validation set
y_pred_prob = complex_nn_model.predict(X_val)
y_pred = (y_pred_prob > 0.5).astype(int)

# Generate the confusion matrix
cm = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:")
print(cm)

# Print classification report (includes F1-score, recall, precision, accuracy)
print("\nClassification Report:")
print(classification_report(y_val, y_pred))
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
# Confusion Matrix:
# [[1675   49]
#  [  73 1671]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      1724
#            1       0.97      0.96      0.96      1744
#
#     accuracy                           0.96      3468
#    macro avg       0.96      0.96      0.96      3468
# weighted avg       0.96      0.96      0.96      3468

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the complex neural network model using Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.0001))(model_input)
    x = BatchNormalization()(x)  # Changed BatchNorm before activation
    x = Dropout(0.3)(x)

    # Layer 2
    x = Dense(4096, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 3
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 4
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Additional Layers
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(128, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(64, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Residual Connection
    residual = Dense(64, activation='relu')(model_input)
    x = Add()([x, residual])

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.0005), loss='binary_crossentropy', metrics=['accuracy'])

# Set up ReduceLROnPlateau and EarlyStopping
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with both callbacks
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr, early_stopping]  # Add early stopping and reduce_lr
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()
# Out:
# Epoch 1/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 29s 61ms/step - accuracy: 0.5825 - loss: 1.6645 - val_accuracy: 0.7275 - val_loss: 1.4264 - learning_rate: 5.0000e-04
# Epoch 2/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 22s 10ms/step - accuracy: 0.6956 - loss: 1.4195 - val_accuracy: 0.7301 - val_loss: 1.3717 - learning_rate: 5.0000e-04
# Epoch 3/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7398 - loss: 1.3192 - val_accuracy: 0.7719 - val_loss: 1.2672 - learning_rate: 5.0000e-04
# Epoch 4/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7538 - loss: 1.2750 - val_accuracy: 0.7832 - val_loss: 1.2137 - learning_rate: 5.0000e-04
# Epoch 5/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7793 - loss: 1.2108 - val_accuracy: 0.7852 - val_loss: 1.1756 - learning_rate: 5.0000e-04
# Epoch 6/200
# 217/217 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7805 - loss: 1.1718 - val_accuracy: 0.7930 - val_loss: 1.1377 - learning_rate: 5.0000e-04
# Epoch 7/200
# ...

# %%
# prompt: call confusion matrix, show f1 score, recall, accuracy.

from sklearn.metrics import confusion_matrix, classification_report

# Make predictions on the validation set
y_pred_prob = complex_nn_model.predict(X_val)
y_pred = (y_pred_prob > 0.5).astype(int)

# Generate the confusion matrix
cm = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:")
print(cm)

# Print classification report (includes F1-score, recall, precision, accuracy)
print("\nClassification Report:")
print(classification_report(y_val, y_pred))
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Confusion Matrix:
# [[1671   53]
#  [  64 1680]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1724
#            1       0.97      0.96      0.97      1744
#
#     accuracy                           0.97      3468
#    macro avg       0.97      0.97      0.97      3468
# weighted avg       0.97      0.97      0.97      3468

# %% [markdown]
# LETS ADD MORE EPOCHS

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Nadam

# Load the dataset
df_train = pd.read_csv("heart_disease_train_resampled.csv")

# Separate the features and target variable
X = df_train.drop("cardio", axis=1)
y = df_train["cardio"]

# Normalize the data
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_normalized, y, test_size=0.2, random_state=42)

# Define the more complex neural network model using the Functional API
def create_complex_nn_model(input_shape):
    model_input = Input(shape=(input_shape,))

    # Layer 1
    x = Dense(4096, activation='relu', kernel_regularizer=l2(0.0001))(model_input)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Layer 2
    x = Dense(8192, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 3
    x = Dense(4096, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 4
    x = Dense(2048, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Layer 5
    x = Dense(1024, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Additional Layers
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(256, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(128, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(64, activation='relu', kernel_regularizer=l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Residual Connection for Stability
    residual = Dense(64, activation='relu')(model_input)
    x = Add()([x, residual])

    # Output Layer
    model_output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=model_input, outputs=model_output)

    return model

# Instantiate the model
complex_nn_model = create_complex_nn_model(X_normalized.shape[1])

# Compile the model with Nadam optimizer and binary crossentropy loss
complex_nn_model.compile(optimizer=Nadam(learning_rate=0.0003), loss='binary_crossentropy', metrics=['accuracy'])

# Set up callbacks for ReduceLROnPlateau and EarlyStopping
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = complex_nn_model.fit(
    X_train, y_train,
    epochs=300,  # Increased epochs for more training
    batch_size=64,
    validation_data=(X_val, y_val),
    callbacks=[reduce_lr, early_stopping]  # EarlyStopping prevents overfitting
)

# Analyze the training history to detect underfitting or overfitting
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# Evaluate the model performance
from sklearn.metrics import confusion_matrix, classification_report

# Predictions on validation set
y_pred = (complex_nn_model.predict(X_val) > 0.5).astype("int32")

# Confusion matrix
conf_matrix = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report
class_report = classification_report(y_val, y_pred)
print("\nClassification Report:")
print(class_report)
# Out:
# Epoch 1/300
#   8/217 ━━━━━━━━━━━━━━━━━━━━ 10:53 3s/step - accuracy: 0.4530 - loss: 2.7500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-59a9b3028a44> in <cell line: 94>()
#      92
#      93 # Train the model
# ---> 94 history = complex_nn_model.fit(
#      95     X_train, y_train,
#      96     epochs=300,  # Increased epochs for more training
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
# prompt: call confusion matrix, show f1 score, recall, accuracy.

from sklearn.metrics import confusion_matrix, classification_report

# Make predictions on the validation set
y_pred_prob = complex_nn_model.predict(X_val)
y_pred = (y_pred_prob > 0.5).astype(int)

# Generate the confusion matrix
cm = confusion_matrix(y_val, y_pred)
print("Confusion Matrix:")
print(cm)

# Print classification report (includes F1-score, recall, precision, accuracy)
print("\nClassification Report:")
print(classification_report(y_val, y_pred))
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix:
# [[1675   49]
#  [  68 1676]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1724
#            1       0.97      0.96      0.97      1744
#
#     accuracy                           0.97      3468
#    macro avg       0.97      0.97      0.97      3468
# weighted avg       0.97      0.97      0.97      3468

# %%
# prompt: Save the model

complex_nn_model.save("my_complex_nn_model.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cc40526f721a> in <cell line: 3>()
#       1 # prompt: Save the model
#       2
# ----> 3 complex_nn_model.save("my_complex_nn_model.h5")
#
# NameError: name 'complex_nn_model' is not defined
